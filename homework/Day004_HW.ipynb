# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
# Out:
# '\nYour Code\n'

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('https://www.hms.gov.taipei/api/BigData/project')
r.text
# Out:
# '[{"name":"內湖區金龍都更分回戶","distict":"內湖區","address":"內湖路3段30號、36號、40號","lat":"25.0855","lng":"121.5927","houseHolds":"","persons":"","floors":"","progress":"已完工"},{"name":"大同區捷運新莊線大橋頭站分回","distict":"大同區","address":"","lat":"25.06321","lng":"121.5117","houseHolds":"","persons":"","floors":"","progress":"已完工"},{"name":"文山區順興都更分回戶","distict":"文山區","address":"臺北市文山區忠順街二段85巷5~11號","lat":"24.98629","lng":"121.5651","houseHolds":"","persons":"","floors":"","progress":"已完工"},{"name":"新北市新店區新店機廠聯開宅","distict":"新店區","address":"新北市 新店區 中央路153號、 161號","lat":"24.973","lng":"121.5299","houseHolds":"99","persons":"151","floors":"","progress":"已完工"},{"name":"士林區永平社會住宅","distict":"士林區","address":"士林區延平北路6段261巷 2號","lat":"25.08886","lng":"121.5038","houseHolds":"51","persons":"153","floors":"","progress":"已完工"},{"name":"大同區大龍峒社會住宅","distict":"大同區","address":"承德路三段212號2-11樓","lat":"25.07136","lng":"121.5181","houseHolds":"110","persons":"190","floors":"","progress":"已完工"},{"name":"南港區東明社會住宅","distict":"南港區","address":"南港區 南港路二段 60巷 16、17、19號","lat":"25.05435","lng":"121.6039","houseHolds":"700","persons":"946","floors":"甲基地:1棟/地上21層地下3層 乙基地:2棟/地上21層地下4層 丙基地:1棟/地上5層地下1層","progress":"已完工"},{"name":"文山區安康平宅BC街廓結構補強 暨室內裝修","distict":"文山區","address":"","lat":"24.98835","lng":"121.558","houseHolds":"","persons":"","floors":"","progress":"已完工"},{"name":"新北市三重區臺北橋聯開宅","distict":"三重區","address":"新北市 三重區 重新路1段118至160號5-27樓","lat":"25.06303","lng":"121.5007","houseHolds":"190","persons":"311","floors":"","progress":"已完工"},{"name":"大同區敦煌社會住宅","distict":"大同區","address":"大同區敦煌路88巷8號2-4樓","lat":"25.07574","lng":"121.517","houseHolds":"3","persons":"9","floors":"","progress":"已完工"},{"name":"中山區新興社會住宅 ","distict":"中山區","address":"中山區 林森北路487號","lat":"25.06139","lng":"121.5264","houseHolds":"37","persons":"106","floors":"","progress":"已完工"},{"name":"萬華區青年社會住宅","distict":"萬華區","address":"萬華區 青年路  186號、188號","lat":"25.01995","lng":"121.504","houseHolds":"273","persons":"393","floors":"18層、14層","progress":"已完工"},{"name":"松山區健康社會住宅","distict":"松山區","address":"松山區 健康路285、 295、305、309、317、 323號","lat":"25.05436","lng":"121.564","houseHolds":"507","persons":"701","floors":"一區：1棟/地上14層地下3層 二區：3棟/地上16層地下3層","progress":"已完工"},{"name":"萬華區龍山寺聯開宅","distict":"萬華區","address":"萬華區 和平西路 3段85號4樓、5樓","lat":"25.03541","lng":"121.5016","houseHolds":"7","persons":"8","floors":"","progress":"已完工"},{"name":"文山區萬隆站社會住宅","distict":"文山區","address":"文山區萬隆里羅斯福路5段214號3-8樓","lat":"25.0029","lng":"121.5386","houseHolds":"41","persons":"46","floors":"","progress":"已完工"},{"name":"大同區明倫社會住宅","distict":"大同區","address":"大龍段一小段259-5地號等10筆","lat":"25.07326","lng":"121.5199","houseHolds":"380","persons":"541","floors":"2棟/地上11層地下2層","progress":"已完工"},{"name":"文山區興隆社會住宅D2區","distict":"文山區","address":"文山區 木柵路2段138巷33號及興隆路 4段105巷45、47號","lat":"24.98789","lng":"121.5623","houseHolds":"510","persons":"788","floors":"3棟/地上11及22層地下5層","progress":"已完工"},{"name":"北投區洲美社會住宅","distict":"北投區","address":"北投區福美路202,203, 207,211, 218,220, 221,222, 225,226號","lat":"25.10014","lng":"121.505","houseHolds":"100","persons":"392","floors":"","progress":"已完工"},{"name":"中山區行天宮站社會住宅","distict":"中山區","address":"中山區松江路273號7-9樓","lat":"25.05997","lng":"121.5335","houseHolds":"30","persons":"30","floors":"","progress":"已完工"},{"name":"文山區木柵社會住宅","distict":"文山區","address":"文山區久康街24巷36、38、40、42、46號","lat":"24.98928","lng":"121.5662","houseHolds":"119","persons":"177","floors":"1棟/地上15層地下4層","progress":"已完工"},{"name":"文山區興隆社會住宅D1區","distict":"文山區","address":"文山區木柵路2段2巷12號","lat":"24.98836","lng":"121.5578","houseHolds":"272","persons":"432","floors":"","progress":"已完工"},{"name":"文山區景文社會住宅","distict":"文山區","address":"文山區景行里羅斯福路六段469巷19號","lat":"24.98989","lng":"121.5406","houseHolds":"42","persons":"104","floors":"","progress":"已完工"},{"name":"南港區中南社會住宅","distict":"南港區","address":"中南段四小段829地號","lat":"25.04282","lng":"121.619","houseHolds":"119","persons":"197","floors":"1棟/地上15層地下3層","progress":"已完工"},{"name":"內湖區瑞光社會住宅","distict":"內湖區", ...

# %%
import json

json.loads(r.text)
# Out:
# [{'name': '內湖區金龍都更分回戶',
#   'distict': '內湖區',
#   'address': '內湖路3段30號、36號、40號',
#   'lat': '25.0855',
#   'lng': '121.5927',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '大同區捷運新莊線大橋頭站分回',
#   'distict': '大同區',
#   'address': '',
#   'lat': '25.06321',
#   'lng': '121.5117',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '文山區順興都更分回戶',
#   'distict': '文山區',
#   'address': '臺北市文山區忠順街二段85巷5~11號',
#   'lat': '24.98629',
#   'lng': '121.5651',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '新北市新店區新店機廠聯開宅',
#   'distict': '新店區',
#   'address': '新北市 新店區 中央路153號、 161號',
#   'lat': '24.973',
#   'lng': '121.5299',
#   'houseHolds': '99',
#   'persons': '151',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '士林區永平社會住宅',
#   'distict': '士林區',
#   'address': '士林區延平北路6段261巷 2號',
#   'lat': '25.08886',
#   'lng': '121.5038',
#   'houseHolds': '51',
#   'persons': '153',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '大同區大龍峒社會住宅',
#   'distict': '大同區',
#   'address': '承德路三段212號2-11樓',
#   'lat': '25.07136',
#   'lng': '121.5181',
#   'houseHolds': '110',
#   'persons': '190',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '南港區東明社會住宅',
#   'distict': '南港區',
#   'address': '南港區 南港路二段 60巷 16、17、19號',
#   'lat': '25.05435',
#   'lng': '121.6039',
#   'houseHolds': '700',
#   'persons': '946',
#   'floors': '甲基地:1棟/地上21層地下3層 乙基地:2棟/地上21層地下4層 丙基地:1棟/地上5層地下1層',
#   'progress': '已完工'},
#  {'name': '文山區安康平宅BC街廓結構補強 暨室內裝修',
#   'distict': '文山區',
#   'address': '',
#   'lat': '24.98835',
#   'lng': '121.558',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '新北市三重區臺北橋聯開宅',
#   'distict': '三重區',
#   'address': '新北市 三重區 重新路1段118至160號5-27樓',
#   'lat': '25.06303',
#   'lng': '121.5007',
#   'houseHolds': '190',
#   'persons': '311',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '大同區敦煌社會住宅',
#   'distict': '大同區',
#   'address': '大同區敦煌路88巷8號2-4樓',
#   'lat': '25.07574',
#   'lng': '121.517',
#   'houseHolds': '3',
#   'persons': '9',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '中山區新興社會住宅 ',
#   'distict': '中山區',
#   'address': '中山區 林森北路487號',
#   'lat': '25.06139',
#   'lng': '121.5264',
#   'houseHolds': '37',
#   'persons': '106',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '萬華區青年社會住宅',
#   'distict': '萬華區',
#   'address': '萬華區 青年路  186號、188號',
#   'lat': '25.01995',
#   'lng': '121.504',
#   'houseHolds': '273',
#   'persons': '393',
#   'floors': '18層、14層',
#   'progress': '已完工'},
#  {'name': '松山區健康社會住宅',
#   'distict': '松山區',
#   'address': '松山區 健康路285、 295、305、309、317、 323號',
#   'lat': '25.05436',
#   'lng': '121.564',
#   'houseHolds': '507',
#   'persons': '701',
#   'floors': '一區：1棟/地上14層地下3層 二區：3棟/地上16層地下3層',
#   'progress': '已完工'},
#  {'name': '萬華區龍山寺聯開宅',
#   'distict': '萬華區',
#   'address': '萬華區 和平西路 3段85號4樓、5樓',
#   'lat': '25.03541',
#   'lng': '121.5016',
#   'houseHolds': '7',
#   'persons': '8',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '文山區萬隆站社會住宅',
#   'distict': '文山區',
#   'address': '文山區萬隆里羅斯福路5段214號3-8樓',
#   'lat': '25.0029',
#   'lng': '121.5386',
#   'houseHolds': '41',
#   'persons': '46',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '大同區明倫社會住宅',
#   'distict': '大同區',
#   'address': '大龍段一小段259-5地號等10筆',
#   'lat': '25.07326',
#   'lng': '121.5199',
#   'houseHolds': '380',
#   'persons': '541',
#   'floors': '2棟/地上11層地下2層',
#   'progress': '已完工'},
#  {'name': '文山區興隆社會住宅D2區',
#   'distict': '文山區',
#   'address': '文山區 木柵路2段138巷33號及興隆路 4段105巷45、47號',
#   'lat': '24.98789',
#   'lng': '121.5623',
#   'houseHolds': '510',
#   'persons': '788',
#   'floors': '3棟/地上11及22層地下5層',
#   'progress': '已完工'},
#  {'name': '北投區洲美社會住宅',
#   'distict': '北投區',
#   'address': '北投區福美路202,203, 207,211, 218,220, 221,222, 225,226號',
#   'lat': '25.10014',
#   'lng': '121.505',
#   'houseHolds': '100',
#   'persons': '392',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '中山區行天宮站社會住宅',
#   'distict': '中山區',
#   'address': '中山區松江路273號7-9樓',
#   'lat': '25.05997',
#   'lng': '121.5335',
#   'houseHolds': '30',
#   'persons': '30',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '文山區木柵社會住宅',
#   'distict': '文山區',
#   'address': '文山區久康街24巷36、38、40、42、46號',
#   'lat': '24.98928',
#   'lng': '121.5662',
#   'houseHolds': '119',
#   'persons': '177',
#   'floors': '1棟/地上15層地下4層',
#   'progress': '已完工'},
#  {'name': '文山區興隆社會住宅D1區',
#   'distict': '文山區',
#   'address': '文山區木柵路2段2巷12號',
#   'lat': '24.98836',
#   'lng': '121.5578',
#   'houseHolds': '272',
#   'persons': '432',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '文山區景文社會住宅',
#   'distict': '文山區',
#   'address': '文山區景行里羅斯福路六段469巷19號',
#   'lat': '24.98989',
#   'lng': '121.5406',
#   'houseHolds': '42',
#   'persons': '104',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '南港區中南社會住宅',
#   'distict': '南港區',
#   'address': '中南段四小段829地號',
#   'lat': '25.04282',
#   'lng': '121.619',
#   'houseHolds': '119',
#   'persons': '197',
#   'floors': '1棟/地上15層地下3層',
#   'progress': '已完工'},
#  {'name': '內湖區瑞光社會住宅',
#   'distict': '內湖區',
#   'address': '文德段五小段155地號',
#   'lat': '25.07336',
#   'lng': '121.579',
#   'houseHolds': '389',
#   'persons': '494',
#   'floors': '1棟/地上14層地下4層',
#   'progress': '已完工'},
#  {'name': '內湖區港墘聯開宅',
#   'distict': '內湖區',
#   'address': '內湖區 內湖路1段659、661號4、5樓',
#   'lat': '25.08032',
#   'lng': '121.5753',
#   'houseHolds': '9',
#   'persons': '11',
#   'floors': '',
#   'progress': '已完工'},
#  {'name': '興隆社會住宅I區',
#   'distict': '文山區',
#   'address': '木柵段三小段674-2、675、714地號',
#   'lat': '24.98694',
#   'lng': '121.5612',
#   'houseHolds': '500',
#   'persons': '736',
#   'floors': '2棟/地上17層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '福星社會住宅',
#   'distict': '萬華區',
#   'address': '福星段一小段240 地號(部分)及256-4 地號等2 筆',
#   'lat': '25.04701',
#   'lng': '121.5065',
#   'houseHolds': '255',
#   'persons': '346',
#   'floors': '1棟/地上17層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '玉成社會住宅 ',
#   'distict': '南港區',
#   'address': '玉成段三小段545地號等8筆',
#   'lat': '25.0485',
#   'lng': '121.5827',
#   'houseHolds': '396',
#   'persons': '532',
#   'floors': '2棟/地上19,21層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '樟新水岸社會住宅 ',
#   'distict': '文山區',
#   'address': '臺北市文山區樟新街及樟新街63巷口',
#   'lat': '24.97746',
#   'lng': '121.5564',
#   'houseHolds': '192',
#   'persons': '258',
#   'floors': '1幢2棟/地上14層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '培英社會住宅 ',
#   'distict': '中山區',
#   'address': '北安段3小段582地號土地',
#   'lat': '25.07977',
#   'lng': '121.5486',
#   'houseHolds': '96',
#   'persons': '128',
#   'floors': '1棟/地上14層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '舊宗社會住宅 ',
#   'distict': '內湖區',
#   'address': '舊宗段57、57-1地號',
#   'lat': '25.06227',
#   'lng': '121.5783',
#   'houseHolds': '97',
#   'persons': '113',
#   'floors': '1棟/地上9層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '景豐一區社會住宅  ',
#   'distict': '文山區',
#   'address': '興隆段二小段230-5、230-36、235-2、240-1地號等4筆土地',
#   'lat': '25.00202',
#   'lng': '121.5449',
#   'houseHolds': '90',
#   'persons': '114',
#   'floors': '1棟/地上14層地下2層',
#   'progress': '施工中及待開工'},
#  {'name': '廣慈博愛園區社會住宅(C基地)',
#   'distict': '信義區',
#   'address': '福德段二小段319地號',
#   'lat': '25.03848',
#   'lng': '121.5817',
#   'houseHolds': '476',
#   'persons': '849',
#   'floors': '2棟/地上28層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '廣慈博愛園區社會住宅(D基地)',
#   'distict': '信義區',
#   'address': '福德段二小段319地號等27筆',
#   'lat': '25.03891',
#   'lng': '121.5814',
#   'houseHolds': '522',
#   'persons': '925',
#   'floors': '2棟/地上27層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '興隆社會住宅E區',
#   'distict': '文山區',
#   'address': '華興段一小段305地號',
#   'lat': '24.98814',
#   'lng': '121.5591',
#   'houseHolds': '263',
#   'persons': '350',
#   'floors': '1棟/地上20層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '斯文里三期都更分回戶',
#   'distict': '大同區',
#   'address': '大同段一小段447-2、465-2地號等2筆',
#   'lat': '25.06715',
#   'lng': '121.517',
#   'houseHolds': '349',
#   'persons': '436',
#   'floors': '1棟/地上13層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '小彎社會住宅',
#   'distict': '南港區',
#   'address': '向陽段35地號土地',
#   'lat': '25.05763',
#   'lng': '121.5936',
#   'houseHolds': '341',
#   'persons': '497',
#   'floors': '2棟/地上10層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '行善社會住宅 ',
#   'distict': '內湖區',
#   'address': '舊宗段40-1地號',
#   'lat': '25.06071',
#   'lng': '121.5815',
#   'houseHolds': '526',
#   'persons': '702',
#   'floors': '2棟/地上10層地下2層',
#   'progress': '施工中及待開工'},
#  {'name': '百齡水岸社會住宅 ',
#   'distict': '士林區',
#   'address': '福順段一小段425、425-1、425-2、425-3、433等六筆',
#   'lat': '25.08014',
#   'lng': '121.5144',
#   'houseHolds': '266',
#   'persons': '363',
#   'floors': '1棟/地上21層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '錦州社會住宅',
#   'distict': '中山區',
#   'address': '吉林段三小段982地號',
#   'lat': '25.05947',
#   'lng': '121.5269',
#   'houseHolds': '387戶',
#   'persons': '504',
#   'floors': '2棟/地上20層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '廣慈博愛園區(A基地)-行政大樓',
#   'distict': '信義區',
#   'address': '福德段二小段319地號等27筆',
#   'lat': '25.03789',
#   'lng': '121.582',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '1棟/地上13層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '新奇岩社會住宅 ',
#   'distict': '北投區',
#   'address': '三合段80地號土地',
#   'lat': '25.12317',
#   'lng': '121.5034',
#   'houseHolds': '288',
#   'persons': '397',
#   'floors': '2棟/地上10層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '和興水岸社會住宅 ',
#   'distict': '文山區',
#   'address': '華興段四小段59地號等28筆',
#   'lat': '24.98477',
#   'lng': '121.5491',
#   'houseHolds': '174',
#   'persons': '251',
#   'floors': '1棟/地上9層地下2層',
#   'progress': '施工中及待開工'},
#  {'name': '經貿社會住宅',
#   'distict': '南港區',
#   'address': '經貿段65地號',
#   'lat': '25.05659',
#   'lng': '121.6103',
#   'houseHolds': '118',
#   'persons': '161',
#   'floors': '1棟/地上12層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '三興社會住宅   ',
#   'distict': '信義區',
#   'address': '三興段三小段422地號等8筆',
#   'lat': '25.02645',
#   'lng': '121.556',
#   'houseHolds': '560',
#   'persons': '783',
#   'floors': '3棟/地上9層、17層、19層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '莒光社會住宅 ',
#   'distict': '萬華區',
#   'address': '莒光段三小段71地號等9筆',
#   'lat': '25.03195',
#   'lng': '121.5',
#   'houseHolds': '201',
#   'persons': '303',
#   'floors': '1棟/地上19層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '南港機廠社會住宅',
#   'distict': '南港區',
#   'address': '南港區新光段一小段4-1地號等83筆土地',
#   'lat': '25.05022',
#   'lng': '121.5971',
#   'houseHolds': '1436',
#   'persons': '1672',
#   'floors': '2棟/地上27層',
#   'progress': '施工中及待開工'},
#  {'name': '興隆社會住宅A區',
#   'distict': '文山區',
#   'address': '華興段一小段254-1、256、258-2地號',
#   'lat': '24.98791',
#   'lng': '121.5598',
#   'houseHolds': '1棟/地上20層地下3層',
#   'persons': '510',
#   'floors': '20',
#   'progress': '施工中及待開工'},
#  {'name': '福國社會住宅 ',
#   'distict': '北投區',
#   'address': '軟橋段64地號',
#   'lat': '25.1021',
#   'lng': '121.5138',
#   'houseHolds': '363',
#   'persons': '471',
#   'floors': '3棟/地上17.15.13層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '華榮市場都更分回戶',
#   'distict': '士林區',
#   'address': '陽明段三小段627地號等3筆',
#   'lat': '25.09644',
#   'lng': '121.5224',
#   'houseHolds': '118',
#   'persons': '173',
#   'floors': '1棟/地上11層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '廣慈博愛園區社會住宅(E基地)',
#   'distict': '信義區',
#   'address': '福德段二小段319地號等27筆',
#   'lat': '25.03944',
#   'lng': '121.5824',
#   'houseHolds': '522',
#   'persons': '933',
#   'floors': '2棟/地上27層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '廣慈博愛園區(B基地)-社福大樓',
#   'distict': '信義區',
#   'address': '福德段二小段319地號等27筆',
#   'lat': '25.03846',
#   'lng': '121.5829',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '1棟/地上8層地下4層',
#   'progress': '施工中及待開工'},
#  {'name': '六張犁A、B區社會住宅 ',
#   'distict': '信義區',
#   'address': '三興段二小段428-76地號等15筆',
#   'lat': '25.02643',
#   'lng': '121.5593',
#   'houseHolds': '709',
#   'persons': '937',
#   'floors': '3棟/地上19層、21層、22地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '青年社會住宅二期',
#   'distict': '萬華區',
#   'address': '臺北市萬華區青年路184號',
#   'lat': '25.02033',
#   'lng': '121.503',
#   'houseHolds': '518',
#   'persons': '762',
#   'floors': '2棟/地上19層地下3層',
#   'progress': '施工中及待開工'},
#  {'name': '景豐二區社會住宅 ',
#   'distict': '文山區',
#   'address': '興隆段二小段235-2,230-36,230-5及240-1地號等共4筆',
#   'lat': '25.00201',
#   'lng': '121.5449',
#   'houseHolds': '114',
#   'persons': '',
#   'floors': '1棟/地上13層地下3層',
#   'progress': '招標中及待上網'},
#  {'name': '延平社會住宅',
#   'distict': '大同區',
#   'address': '大同區延平段一小段42-1、102、103地號',
#   'lat': '25.06224',
#   'lng': '121.5127',
#   'houseHolds': '56',
#   'persons': '',
#   'floors': '1棟/地上11層地下3層',
#   'progress': '招標中及待上網'},
#  {'name': '力行社會住宅',
#   'distict': '中山區',
#   'address': '中山區長安段一小段730、731地號',
#   'lat': '25.0502',
#   'lng': '121.5383',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '招標中及待上網'},
#  {'name': '福民社會住宅一期',
#   'distict': '萬華區',
#   'address': '萬華區雙園段一小段248、248-2、562-1、563地號等7筆土地',
#   'lat': '25.0274',
#   'lng': '121.4908',
#   'houseHolds': '345',
#   'persons': '',
#   'floors': '1棟/地上14層地下4層',
#   'progress': '招標中及待上網'},
#  {'name': '金華社會住宅 (特四、五)',
#   'distict': '大安區',
#   'address': '特四基地： 大安區金華段三小段 146-2、146-3地號等2筆土地  特五基地： 大安區金華段三小段145-1（歷史建築）、146、146-1、146-7（歷史建築）、148-2、149-2地號等6筆土地',
#   'lat': '25.03078',
#   'lng': '121.5256',
#   'houseHolds': '515',
#   'persons': '',
#   'floors': '規劃中',
#   'progress': '招標中及待上網'},
#  {'name': '興隆社會住宅FH區',
#   'distict': '文山區',
#   'address': '木柵段三小段710、712地號',
#   'lat': '24.98739',
#   'lng': '121.5611',
#   'houseHolds': '447',
#   'persons': '',
#   'floors': '1棟/地上23層地下4層',
#   'progress': '規劃中'},
#  {'name': '台肥丁社會住宅',
#   'distict': '南港區',
#   'address': '',
#   'lat': '25.0539',
#   'lng': '121.6018',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '松信社會住宅',
#   'distict': '信義區',
#   'address': '信義區雅祥段3小段357地號',
#   'lat': '25.04251',
#   'lng': '121.5717',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '東湖社會住宅',
#   'distict': '內湖區',
#   'address': '內湖區東湖段7小段484地號',
#   'lat': '25.06709',
#   'lng': '121.6133',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '保養廠社會住宅',
#   'distict': '南港區',
#   'address': '',
#   'lat': '25.0412',
#   'lng': '121.5934',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '福民社會住宅二期',
#   'distict': '萬華區',
#   'address': '雙園段一小段246、248地號等2筆土地',
#   'lat': '25.02758',
#   'lng': '121.491',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '奇岩社會住宅',
#   'distict': '北投區',
#   'address': '',
#   'lat': '25.12818',
#   'lng': '121.5086',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '僑泰興社會住宅',
#   'distict': '南港區',
#   'address': '',
#   'lat': '25.05437',
#   'lng': '121.6104',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'},
#  {'name': '潭美國小基地社會住宅',
#   'distict': '內湖區',
#   'address': '',
#   'lat': '25.06082',
#   'lng': '121.5902',
#   'houseHolds': '',
#   'persons': '',
#   'floors': '',
#   'progress': '規劃中'}]
