# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import pandas as pd
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response
# Out:
# '[{"id":236178867,"title":"第一屆貓貓睡死大賽","excerpt":"我就從最近到以前的照片，慢慢po出來，不行了，我的相簿照片有一萬多張，憨吉照片最少佔了80%，睡覺的照片我預估也有快一千張，就先這樣吧，接下來各位同學，也可以出賣自己主子的睡覺照，我最近發現一招，如果","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","commentCount":85,"likeCount":303,"withNickname":true,"tags":[],"topics":["貓貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"M","school":"延平北路最會養貓的男人","department":"mark20171107","replyTitle":null,"mediaMeta":[{"id":"cac3bbef-2ab0-4d71-96a0-ce1c272e1a84","url":"https://i.imgur.com/CA6pPO3l.jpg","normalizedUrl":"https://i.imgur.com/CA6pPO3l.jpg","thumbnail":"https://i.imgur.com/CA6pPO3l.jpg","type":"image/thumbnail","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000,"croppingWindow":{"anchorX":0,"anchorY":0,"width":1500,"height":2000}},{"id":"cac3bbef-2ab0-4d71-96a0-ce1c272e1a84","url":"https://i.imgur.com/CA6pPO3.jpg","normalizedUrl":"https://imgur.com/CA6pPO3","thumbnail":"https://i.imgur.com/CA6pPO3l.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000,"croppingWindow":{"anchorX":0,"anchorY":0,"width":1500,"height":2000}},{"id":"fcce0c5a-baca-4931-9785-6a0d96be8e8a","url":"https://i.imgur.com/JUK2tOo.jpg","normalizedUrl":"https://imgur.com/JUK2tOo","thumbnail":"https://i.imgur.com/JUK2tOol.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"306b4df5-9061-4b61-9867-aae57695cac5","url":"https://i.imgur.com/FpxCZR8.jpg","normalizedUrl":"https://imgur.com/FpxCZR8","thumbnail":"https://i.imgur.com/FpxCZR8l.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"eda49886-8a99-45c0-a512-15ee25eed089","url":"https://i.imgur.com/MVLXRaX.jpg","normalizedUrl":"https://imgur.com/MVLXRaX","thumbnail":"https://i.imgur.com/MVLXRaXl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"e3a5b097-802a-4e5e-b7c8-299d1506266d","url":"https://i.imgur.com/tacqhXd.jpg","normalizedUrl":"https://imgur.com/tacqhXd","thumbnail":"https://i.imgur.com/tacqhXdl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"b6734ca4-c1b5-4730-ba67-e43af76021ca","url":"https://i.imgur.com/iewhEkR.jpg","normalizedUrl":"https://imgur.com/iewhEkR","thumbnail":"https://i.imgur.com/iewhEkRl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"b82d4e36-abe7-466d-aeb7-d7ac21b394cd","url":"https://i.imgur.com/BPaEj0B.jpg","normalizedUrl":"https://imgur.com/BPaEj0B","thumbnail":"https://i.imgur.com/BPaEj0Bl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":2000,"height":1500},{"id":"40374d3b-ed31-4a58-b649-629a1b5c9b6c","url":"https://i.imgur.com/oR9gaF1.jpg","normalizedUrl":"https://imgur.com/oR9gaF1","thumbnail":"https://i.imgur.com/oR9gaF1l.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"1afb03ee-417e-4527-9b69-499a11bcca68","url":"https://i.imgur.com/e35aHo3.jpg","normalizedUrl":"https://imgur.com/e35aHo3","thumbnail":"https://i.imgur.com/e35aHo3l.jpg","type":"image/imgur","tags":[],"createdAt":"2021-06-05T09:28:06.587Z","updatedAt":"2021-06-05T09:28:06.587Z","width":1500,"height":2000},{"id":"642da084-e3e8-4183-b3ac-e805fc32cd11","url":"https://i.imgur.com/D66f4vx.jpg","normalizedUrl":"http ...

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
import json
data = json.loads(response)
print (data[1].keys()) #list 裡第一格的字典裡的key值
print(len(data)) #有幾筆資料
for d in data:
    print(d['title'],d['createdAt'],d['commentCount'],d['likeCount'])
df = pd.DataFrame(data)
df.columns.values
'''print(len(d)) #變數數量
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'isModerator', 'layout', 'spoilerAlert', 'withImages', 'withVideos', 'media', 'reportReasonText', 'excerptComments', 'postAvatar', 'verifiedBadge', 'memberType'])
# 30
# 第一屆貓貓睡死大賽 2021-06-05T09:28:06.587Z 85 303
# 誰來把我帶回家 2021-06-05T03:08:12.520Z 34 197
# 疫情期間只能整天吸貓ㄌ！ 2021-06-05T11:03:51.105Z 13 169
# 高雄惡劣的動物醫院 2021-06-05T02:07:56.236Z 21 121
# 一年以來🥰🥰🥰 2021-06-05T18:56:29.275Z 15 97
# 星狀飼料 2021-06-05T21:12:32.130Z 11 91
# 喵喵特殊名字大集合 2021-06-05T14:02:50.142Z 42 67
# 生小孩後貓咪都關籠 2021-06-04T22:54:33.841Z 15 53
# 請提供橘貓料理方法 2021-06-05T02:36:37.646Z 21 51
# 狗子都怎麼說早安🥰 2021-06-06T02:36:48.427Z 6 48
# 最擔憂最害怕的事情終究還是來了。 2021-06-05T16:48:34.802Z 3 39
# 宜家寵物睡窩推薦 2021-06-05T17:29:29.428Z 16 37
# 拜託各位蘆洲的朋友幫幫我😭 2021-06-05T13:17:10.573Z 9 35
# 澎湖再傳浪浪侵門踏戶 破壞紗窗入屋咬死寵物貓 2021-06-05T12:28:48.146Z 2 32
# #圖 新手領養貓咪 分享 2021-06-05T04:29:37.552Z 12 31
# 瑪爾濟斯結紮變摘胰臟亡.. 2021-06-05T20:00:46.563Z 5 26
# 貓與紙箱的關係📦 2021-06-06T04:38:24.403Z 4 25
# 奇異的散熱姿勢 2021-06-05T09:56:08.967Z 0 22
# 大家好 我叫做豆皮～ 2021-06-05T21:52:44.086Z 4 16
# 被我媽叫來的烏龜 2021-06-05T13:30:00.945Z 4 16
# 極品貓爪陪你上課 2021-06-05T11:13:25.037Z 2 14
# 不受貓喜歡的奴才 2021-06-05T13:22:55.920Z 6 12
# 小笨狗 2021-06-05T11:22:00.193Z 5 10
# 卯迷搞得迷迷卯卯＃圖 2021-06-06T08:19:44.544Z 1 9
# 海苔米菓菓小兔兔 2021-06-06T05:58:13.076Z 4 9
# 蘆洲尋貓啟事 2021-06-05T13:47:51.812Z 4 9
# 北港溪河堤公園狗群圍咬落單民眾影片曝光 已有4人受傷 2021-06-05T05:21:49.123Z 4 8
# CC營養糊 2021-06-05T03:48:04.279Z 7 8
# #圖 肛門附近紅腫 2021-06-05T15:57:19.729Z 1 6
# 有沒有人跟我一樣只能這樣看狗狗 2021-06-05T09:52:17.605Z 0 6
# array(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment',
#        'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt',
#        'commentCount', 'likeCount', 'withNickname', 'tags', 'topics',
#        'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school',
#        'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden',
#        'customStyle', 'isSuspiciousAccount', 'isModerator', 'layout',
#        'spoilerAlert', 'withImages', 'withVideos', 'media',
#        'reportReasonText', 'excerptComments', 'postAvatar',
#        'verifiedBadge', 'memberType', 'categories'], dtype=object)

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

Totalcomment = 0 
Totallike = 0

for d in data:
    Totalcomment = Totalcomment + d['commentCount']
    Totallike = Totallike + d['likeCount']
print('熱門文章')    
print('總留言數',Totalcomment,'總按讚數',Totallike)
print('平均留言數',round(Totalcomment/len(data),1),'平均按讚數',round(Totallike/len(data),1))


f = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
fdata = json.loads(f.text) 

fTotalcomment = 0 
fTotallike = 0

for f in fdata:
    fTotalcomment = fTotalcomment + f['commentCount']
    fTotallike = fTotallike + f['likeCount']
print('非熱門文章')        
print('總留言數',fTotalcomment,'總按讚數',fTotallike)
print('平均留言數',round(fTotalcomment/len(data),1),'平均按讚數',round(fTotallike/len(data),1))
# Out:
# 熱門文章
# 總留言數 356 總按讚數 1567
# 平均留言數 11.9 平均按讚數 52.2
# 非熱門文章
# 總留言數 92 總按讚數 404
# 平均留言數 3.1 平均按讚數 13.5
